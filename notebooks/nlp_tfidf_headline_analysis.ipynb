# %%
import os 
import sys
import pandas as pd

# Input for this notebook is in the output folder of the ytd script in reports
input_folder = os.path.join(os.path.dirname("."), '..', 'output')

data = pd.read_csv(os.path.join(input_folder, 'td_ytd_report_21052025.csv'), delimiter=',')

# %%
data.head(5)
# Out:
#                                                title  \
# 0    'Conversazioni con altre donne' di Filippo Conz
# 1     'Dune - Parte Due' - I nuovi figli del deserto
# 2  'Il Signore degli Anelli - La guerra dei Rohir...
# 3  15 emozionanti film drammatici da aggiungere a...
# 4  Gennaio 2025 su Prime Video: i migliori titoli...
#
#                                                 link              category  \
# 0  https://www.taxidrivers.it/304488/live-streami...            Recensioni
# 1  https://www.taxidrivers.it/342136/review/dune-...            Recensioni
# 2  https://www.taxidrivers.it/418080/review/in-sa...  Recensioni / In Sala
# 3  https://www.taxidrivers.it/419437/guide-2/15-f...                 Altro
# 4  https://www.taxidrivers.it/419529/live-streami...            Recensioni
#
#                                             pagepath  \
# 0  /304488/live-streaming-on-demand/paramount-str...
# 1  /342136/review/dune-parte-due-i-nuovi-figli-de...
# 2  /418080/review/in-sala/il-signore-degli-anelli...
# 3  /419437/guide-2/15-film-drammatici-da-non-perd...
# 4  /419529/live-streaming-on-demand/gennaio-2025-...
#
#                      pubdate  views  active users  views per active user  \
# 0  2025-01-01 06:00:03+00:00   29.0          23.0               1.260870
# 1  2025-01-01 08:30:14+00:00    NaN           NaN                    NaN
# 2  2025-01-02 05:05:31+00:00   29.0          27.0               1.074074
# 3  2025-01-02 05:00:39+00:00   56.0          48.0               1.166667
# 4  2025-01-01 19:21:48+00:00  411.0         358.0               1.148045
#
#    average engagement time per active user  \
# 0                                60.000000
# 1                                      NaN
# 2                                42.333333
# 3                                48.541667
# 4                                51.594972
#
#                                _yoast_wpseo_focuskw  \
# 0                     Conversazione con altre donne
# 1                                    dune parte due
# 2  Il Signore degli Anelli - La guerra dei Rohirrim
# 3                                   film drammatici
# 4                          gennaio 2025 prime video
#
#                                _yoast_wpseo_metadesc  _yoast_wpseo_linkdex  \
# 0  'Conversazione con altre donne' e l'opera prim...                  80.0
# 1  Anni dopo il primo capitolo, 'Dune - Parte Due...                  77.0
# 2  Il Signore degli Anelli - La guerra dei Rohirr...                  80.0
# 3  Se siete amanti dei film drammatici, ecco per ...                  71.0
# 4  I migliori titoli in uscita a gennaio 2025 su ...                  76.0
#
#    diff_with_daily_benchmark_views  diff_with_daily_benchmark_active_users  \
# 0                             -8.0                                    -6.0
# 1                              NaN                                     NaN
# 2                              0.0                                     0.0
# 3                             27.0                                    21.0
# 4                            374.0                                   329.0
#
#    diff_with_daily_benchmark_average_engagement_time_per_active_user  \
# 0                                          13.833333
# 1                                                NaN
# 2                                           0.000000
# 3                                           6.208333
# 4                                           5.428305
#
#   views_bucket active_users_bucket  \
# 0        Basso         Molto Basso
# 1          NaN                 NaN
# 2        Medio               Medio
# 3   Molto Alto          Molto Alto
# 4   Molto Alto          Molto Alto
#
#   average_engagement_time_per_active_user_bucket
# 0                                           Alto
# 1                                            NaN
# 2                                          Medio
# 3                                           Alto
# 4                                           Alto

# %% [markdown]
# ## An approach to news headlines clustering using K-means
#
# K-Means is a widely used clustering algorithm that partitions data into
# 𝑘
# k clusters based on feature similarity.
#
# Approach: Transform headlines into numerical vectors using techniques like Term Frequency-Inverse Document Frequency (TF-IDF), often incorporating n-grams (e.g., bigrams, trigrams) to capture structural patterns. Then, apply K-Means clustering to group similar headlines.
#
# Example: A GitHub project demonstrates clustering news headlines using K-Means, where headlines are vectorized based on n-gram features.
#
# Per un guida in italiano: https://www.diariodiunanalista.it/posts/come-calcolare-la-similarita-tra-testi-di-un-sito-web-con-tf-idf-in-python/
#
#
# For a great explanation on **how to visualize text clusters in low-dimensional space: https://medium.com/@RobuRishabh/clustering-text-data-with-k-means-and-visualizing-with-t-sne-9bc1fe7d8fed

# %%
# https://www.diariodiunanalista.it/posts/raggruppamento-testuale-con-tf-idf/

import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
import string

from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\manuel.deluzi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\manuel.deluzi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
ita_stopwords = stopwords.words('italian') # List of words
ita_stopwords[0:5] # Print the first 5 italian stop words
# Out:
# ['ad', 'al', 'allo', 'ai', 'agli']

# %%
from sklearn.feature_extraction import TfidfVectorizer


remove_punctuation_map  = dict((ord(char), None) for char in string.punctuation)

def preprocess(text):
    text = text.translate(remove_punctuation_map) #https://www.w3schools.com/python/ref_string_translate.asp
    text = text.lower()
    text = text.strip()
    return nltk.word_tokenize(text)

vectorizer = TfidfVectorizer(tokenizer=preprocess, stop_words=ita_stopwords)

def compute_similarity(a, b):
  tfidf = vectorizer.fit_transform([a, b])
  return ((tfidf * tfidf.T).toarray())[0,1] # This computes the cosine similarity between the two vectors. Since TF-IDF vectors are normalized by default, the dot product of the two gives the cosine similarity.

titles = data['title'].values

M = np.zeros((titles.shape[0], titles.shape[0]))

for i, row in tqdm(enumerate(titles), total=titles.shape[0], desc='1st level'):
	for j, next_row in enumerate(titles):
		M[i, j] = compute_similarity(row, next_row)
# Out:
# 1st level:   0%|          | 0/2862 [00:00<?, ?it/s]
# c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\sklearn\feature_extraction\text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 1st level: 100%|██████████| 2862/2862 [1:50:51<00:00,  2.32s/it]

# %%
similarity_df = pd.DataFrame(M, columns=titles, index=titles)

similarity_df[similarity_df.columns.str.match(".*si farà.*", case=False)]
# Out:
# Empty DataFrame
# Columns: ['Conversazioni con altre donne' di Filippo Conz, 'Dune - Parte Due' - I nuovi figli del deserto, 'Il Signore degli Anelli - La guerra dei Rohirrim': uno spinoff bipolare, 15 emozionanti film drammatici da aggiungere alla tua lista, Gennaio 2025 su Prime Video: i migliori titoli in arrivo!, 'Attack on Titan: The Last Attack': la fine di una saga durata 10 anni, I nuovi film al cinema dal 1° gennaio e quelli ancora in sala, 'Avicii - I'm Tim': La stella cadente della musica, 'The Walking dead: the ones who live' Il ritorno di Rick Grimes, 'Blink' - il documentario della National Geographic, 'Kung Fu Panda 4' - Il panda e l'Apprendista Dragone, 'Maria', la Callas secondo Pablo Larraín e Angelina Jolie, Jacques Audiard: identita, trasformazione e rinascita al cinema, 'Nosferatu' Un omaggio in grande stile che richiede impegno, I migliori musical degli ultimi anni da vedere su Netflix, Il Manifesto sull'asincronismo: criticita e rischi nel cinema sonoro, Elio Germano: un attore dai mille volti, 'Il Vostro Amichevole Spider-Man di quartiere' arriva su Disney+, 'L'onda lunga' la lotta d'autore, 'The Walking dead' le novita del franchise, 'Godzilla e Kong - Il Nuovo Impero': un film di intrattenimento che non intrattiene, 'Marcello Mio': l'audiorecensione, Apple TV+ regala un weekend imperdibile, 'Modern Love Mumbai 2' si fara?, 'Il Padrino - Parte 2' : l'onore e il tempo, 'Dune 4' si fara? In cantiere anche una serie tv. senza Villeneuve!, 'Judy': Tom Cruise e Alejandro González Iñárritu pronti a conquistare il grande schermo, 'Kung Fu Panda 4' arriva su Sky Cinema, 'Alice in Borderland 3' e vicina. Quando arriva su Netflix?, Montaggio Cucine e Servizi per la Casa a Berlino: Professionalita e Esperienza per la Comunita Italiana, 'Mexico! Un cinema alla riscossa'. Omaggio ad Antonio Sancassani, 'Cronaca di un amore': film d'esordio di Antonioni, Il cinema di Joe Wright, amante dello stile e della poesia, 'Billy' conversazione con Emilia Mazzacurati, 'Billy' una favola on the road, 5 film da vedere il giorno della Befana, 'Pino Daniele - Nero a meta', il sala il doc sul celebre cantautore, 'Never Too Late', un pianeta da salvare, 'M- Il figlio del secolo' La nascita di un capolavoro raccontata in conferenza stampa, I film piu attesi nel 2025, I migliori gangster movie di sempre. Guida al genere, I titoli che concorreranno ai Festival nel 2025, The Room Next Door, La Stanza Accanto., 'Lucciole'. Personaggi alla ricerca d'ossigeno per non spegnersi, 'BAFTA 2025': Emilia Perez e Conclave dominano le nomination, 'Il mestiere di vivere' al cinema, Golden Globe 2025: i favoriti per la vittoria, Nosferatu e Dracula i vampiri protagonisti al cinema, Golden Globes 2025 i vincitori, Le migliori pubblicita televisive sul gioco d'azzardo: annunci vincenti che hanno catturato il pubblico, 'Amore Tossico' di Claudio Caligari, 'Green Book': la recensione, Scopriamo assieme l'attore Luca Marinelli: cosa c'e da sapere, 'Mon Crime - La colpevole sono io' di François Ozon, 'Madame Clicquot' : Haley Bennett protagonista di un biopic su identita e diritti delle Donne, 'English Teacher' - Un Brooklyn Nine-Nine a scuola, 'Mica e colpa mia': comicita e romanticismo partenopeo, 'La strana signora della porta accanto' - Un thriller che non ti aspetti, Arriva in prima TV 'Vermiglio': dove e quando guardarlo, 'Here': un secolare piano sequenza sull'esistenza umana, The Independent: le migliori attrici e i migliori attori del XXI secolo, 'L'ultima settimana di settembre' - Un road movie tutto italiano, 'Togo - Una grande amicizia', il migliore amico dell'uomo, 'Heretic', Hugh Grant e un uomo tanto affascinante quanto spietato, "Trailer of the film that will never exist: Phony Wars", Demi Moore vince alla grande ai Golden Globes '25, Alec Baldwin e Luisa Rubino, volto iconico della serie Netflix Narcos: Mexico, a Sorrento per un poliziesco italiano, 'C'e ancora domani', il film della Cortellesi puo gareggiare in alcune categorie degli Oscar, 'Watchful Eye ...
# Index: []
#
# [0 rows x 2862 columns]

# %%
# Find most similar articles

def find_most_similar_articles(title, similarity_df, top_n=5):
    if title not in similarity_df.columns:
        raise ValueError("Title not found in similarity DataFrame.")
    # Get the similarity scores for the given title
    similar_scores = similarity_df[title]
    # Get the top N most similar articles
    most_similar = similar_scores.nlargest(top_n + 1).iloc[1:]
    return most_similar

find_most_similar_articles("'Modern Love Mumbai 2' si fara?", similarity_df)
# Out:
# 'Cassandra 2': si fara?                   0.356300
# 'Storia della mia famiglia 2' si fara?    0.291219
# 'La terra sull'Abisso 2' si fara?         0.291219
# 'Ransom Canyon 2' si fara?                0.291219
# 'Il Giardiniere' stagione 2: si fara?     0.291219
# Name: 'Modern Love Mumbai 2' si fara?, dtype: float64

# %%
# K-means
from sklearn.cluster import KMeans

# Number of clusters (choose based on your dataset)
num_clusters = 3

# Apply K-Means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(M)

# Output the cluster labels for each document
labels = kmeans.labels_
print("Cluster Labels:", labels)

# Assign cluster labels to the original DataFrame
data['cluster'] = labels

data[data['cluster'] == 2].head(20)
# Out:
# Cluster Labels: [1 1 1 ... 1 1 1]
#                                                  title  \
# 25   'Dune 4' si fara? In cantiere anche una serie ...
# 66   Alec Baldwin e Luisa Rubino, volto iconico del...
# 100  'Senna': l'audiorecensione della nuova miniser...
# 103  'ACAB: la serie' dal 15 gennaio su Netflix. Ec...
# 112  'M. Il figlio del secolo' l'imperdibile serie ...
# 114  'American Primeval', la nuova perla western fi...
# 141      'Lockerbie' la serie Sky sull'attentato aereo
# 174        'ACAB: la serie'. Gli occhi dietro i caschi
# 180  'Il conte di Montecristo', la serie: intervist...
# 198  'On call' -  La nuova serie poliziesca prodott...
# 200  I nuovi episodi di 'M - Il figlio del secolo' ...
# 226            Apple Tv+ cancella una celebre serie tv
# 240     'ACAB - La serie': intervista a cast e regista
# 259           Le migliori serie di spionaggio del 2024
# 305     'ACAB: la serie 2' si fara? Ecco cosa sappiamo
# 360  'Enigma Variations': Jeremy Allen White star d...
# 406  'Mercoledi 2': nuovo teaser della serie con Je...
# 408  "Il Gattopardo": importanti novita della serie...
# 415  'On Call': audiorecensione della nuova serie p...
# 417  'Il Mostro di Firenze' il trailer ufficiale de...
#
#                                                   link              category  \
# 25   https://www.taxidrivers.it/419794/latest-news/...                  News
# 66   https://www.taxidrivers.it/420166/latest-news/...                  News
# 100  https://www.taxidrivers.it/420445/review/in-sa...  Recensioni / In Sala
# 103  https://www.taxidrivers.it/420566/latest-news/...                  News
# 112  https://www.taxidrivers.it/395812/serie-tv/sky...              Serie TV
# 114  https://www.taxidrivers.it/420424/serie-tv/net...              Serie TV
# 141  https://www.taxidrivers.it/420932/latest-news/...                  News
# 174  https://www.taxidrivers.it/421078/serie-tv/net...              Serie TV
# 180  https://www.taxidrivers.it/421329/magazine-2/i...   Speciali e Magazine
# 198  https://www.taxidrivers.it/420910/serie-tv/pri...              Serie TV
# 200  https://www.taxidrivers.it/421495/latest-news/...                  News
# 226  https://www.taxidrivers.it/421806/latest-news/...                  News
# 240  https://www.taxidrivers.it/421965/trailers/vid...              Trailers
# 259  https://www.taxidrivers.it/421798/magazine-2/g...   Speciali e Magazine
# 305  https://www.taxidrivers.it/422721/latest-news/...         Anticipazioni
# 360  https://www.taxidrivers.it/423285/latest-news/...         Anticipazioni
# 406  https://www.taxidrivers.it/423767/latest-news/...                  News
# 408  https://www.taxidrivers.it/423830/latest-news/...                  News
# 415  https://www.taxidrivers.it/423452/review/in-sa...  Recensioni / In Sala
# 417  https://www.taxidrivers.it/423851/trailers/htt...              Trailers
#
#                                               pagepath  \
# 25   /419794/latest-news/dune-4-si-fara-in-cantiere...
# 66   /420166/latest-news/alec-baldwin-e-luisa-rubin...
# 100  /420445/review/in-sala/podcast/senna-l-audiore...
# 103  /420566/latest-news/acab-la-serie-dal-15-genna...
# 112  /395812/serie-tv/sky-serie-tv/m-il-figlio-del-...
# 114  /420424/serie-tv/netflix-serie-tv/american-pri...
# 141  /420932/latest-news/lockerbie-la-serie-sky-sul...
# 174  /421078/serie-tv/netflix-serie-tv/acab-la-seri...
# 180  /421329/magazine-2/il-conte-di-montecristo-la-...
# 198  /420910/serie-tv/prime-video-serietv/on-call-l...
# 200  /421495/latest-news/i-nuovi-episodi-di-m-il-fi...
# 226  /421806/latest-news/apple-tv-cancella-una-cele...
# 240  /421965/trailers/videorecensioni/acab-la-serie...
# 259  /421798/magazine-2/guide/le-migliori-serie-di-...
# 305  /422721/latest-news/anticipazioni/acab-la-seri...
# 360  /423285/latest-news/anticipazioni/enigma-varia...
# 406  /423767/latest-news/mercoledi-2-nuovo-teaser-d...
# 408  /423830/latest-news/il-gattopardo-importanti-n...
# 415  /423452/review/in-sala/podcast/on-call-audiore...
# 417  /423851/trailers/https-youtu-be-qvqpoecean0sin...
#
#                        pubdate   views  active users  views per active user  \
# 25   2025-01-03 18:41:30+00:00    27.0          15.0               1.800000
# 66   2025-01-07 09:59:16+00:00    17.0          17.0               1.000000
# 100  2025-01-09 11:06:14+00:00    33.0          17.0               1.941176
# 103  2025-01-10 14:46:09+00:00     NaN           NaN                    NaN
# 112  2025-01-12 05:30:39+00:00    73.0          61.0               1.196721
# 114  2025-01-11 08:53:24+00:00   216.0         162.0               1.333333
# 141  2025-01-13 17:37:44+00:00    13.0          12.0               1.083333
# 174  2025-01-16 06:03:49+00:00    94.0          79.0               1.189873
# 180  2025-01-16 13:52:11+00:00     NaN           NaN                    NaN
# 198  2025-01-17 09:29:56+00:00    73.0          58.0               1.258621
# 200  2025-01-17 10:16:38+00:00    46.0          37.0               1.243243
# 226  2025-01-19 12:27:21+00:00    28.0          26.0               1.076923
# 240  2025-01-20 13:07:55+00:00     NaN           NaN                    NaN
# 259  2025-01-22 05:35:14+00:00   281.0         220.0               1.277273
# 305  2025-01-24 18:10:48+00:00  1899.0        1705.0               1.113783
# 360  2025-01-29 00:55:49+00:00     NaN           NaN                    NaN
# 406  2025-01-31 19:25:34+00:00    54.0          51.0               1.058824
# 408  2025-02-01 13:43:53+00:00    27.0          21.0               1.285714
# 415  2025-02-03 20:26:53+00:00    23.0          15.0               1.533333
# 417  2025-02-02 13:36:21+00:00   180.0         155.0               1.161290
#
#      average engagement time per active user  \
# 25                                 33.333333
# 66                                 46.882353
# 100                                13.294118
# 103                                      NaN
# 112                                78.655738
# 114                                50.716049
# 141                                25.000000
# 174                                59.303797
# 180                                      NaN
# 198                                34.827586
# 200                                49.054054
# 226                                41.653846
# 240                                      NaN
# 259                                43.445455
# 305                                36.564223
# 360                                      NaN
# 406                                25.725490
# 408                                22.904762
# 415                                26.666667
# 417                                15.541935
#
#                    _yoast_wpseo_focuskw  \
# 25                               Dune 4
# 66                         Alec Baldwin
# 100                               Senna
# 103                      ACAB: la serie
# 112             M. Il figlio del secolo
# 114                   American Primeval
# 141                           lockerbie
# 174                      ACAB: la serie
# 180             il conte di Montecristo
# 198                             On call
# 200               I nuovi episodi di 'M
# 226                           apple tv+
# 240  ACAB - la serie intervista al cast
# 259                 serie di spionaggio
# 305                    ACAB: la serie 2
# 360                   Enigma Variations
# 406            Mercoledi 2 nuovo teaser
# 408                       Il Gattopardo
# 415                             On Call
# 417        il mostro di firenze trailer
#
#                                  _yoast_wpseo_metadesc  _yoast_wpseo_linkdex  \
# 25   Dune 4 si fara? Ecco quello che sappiamo al mo...                  69.0
# 66   A Sorrento riprese per un lungometraggio che v...                  63.0
# 100  Emanuela Nizzari ci racconta Senna, la miniser...                  74.0
# 103  'ACAB: la serie' e in arrivo il 15 gennaio su ...                  82.0
# 112  A Venezia 2024 arriva M. Il figlio del secolo,...                  63.0
# 114  Su Netflix la serie originale American Primeva...                  80.0
# 141  Dal 27 Gennaio 2025 su Sky la nuova serie orig...                  79.0
# 174  La recensione dei primi episodi di 'ACAB: la s...                  83.0
# 180  Il regista della miniserie 'il conte di Montec...                  82.0
# 198  "On call" - La nuova serie poliziesca disponib...                  79.0
# 200  Disponibili dal 17 gennaio i nuovi episodi di ...                  71.0
# 226  Questa importante serie e stata appena cancell...                  78.0
# 240  Nicola Roumeliotis ha intervistato per noi cas...                  72.0
# 259  In questa guida abbiamo raccolto tre serie tv ...                  74.0
# 305  'ACAB: la serie 2' e realta? Vediamo cosa sapp...                  85.0
# 360  Enigma Variations: La star di The Bear e Shame...                  83.0
# 406  Pubblicato sui canali ufficiali il nuovo tease...                  69.0
# 408  Ufficializzata la data di uscita della serie t...                  74.0
# 415  Carmen Marinacci ci parla di On Call, la nuova...                  80.0
# 417  il mostro di firenze trailer online del serial...                  73.0
#
#      diff_with_daily_benchmark_views  diff_with_daily_benchmark_active_users  \
# 25                             -12.0                                   -11.0
# 66                             -10.5                                    -5.5
# 100                             -2.0                                   -10.0
# 103                              NaN                                     NaN
# 112                             35.0                                    33.5
# 114                            174.0                                   134.0
# 141                             -4.0                                    -5.0
# 174                             61.0                                    53.5
# 180                              NaN                                     NaN
# 198                             37.0                                    30.0
# 200                             10.0                                     9.0
# 226                             -7.5                                     1.0
# 240                              NaN                                     NaN
# 259                            263.5                                   206.5
# 305                           1875.0                                  1684.0
# 360                              NaN                                     NaN
# 406                             22.0                                    26.0
# 408                             -1.0                                    -1.5
# 415                              0.5                                    -2.0
# 417                            149.0                                   127.0
#
#      diff_with_daily_benchmark_average_engagement_time_per_active_user  \
# 25                                            1.166667
# 66                                            5.350871
# 100                                         -20.831584
# 103                                                NaN
# 112                                          43.803059
# 114                                          27.100832
# 141                                          -0.666667
# 174                                          23.377131
# 180                                                NaN
# 198                                           1.952586
# 200                                          16.179054
# 226                                           7.689148
# 240                                                NaN
# 259                                          10.843182
# 305                                           7.711544
# 360                                                NaN
# 406                                         -19.789661
# 408                                         -32.561905
# 415                                          -7.158692
# 417                                         -19.724731
#
#     views_bucket active_users_bucket  \
# 25   Molto Basso         Molto Basso
# 66   Molto Basso               Basso
# 100        Basso         Molto Basso
# 103          NaN                 NaN
# 112   Molto Alto          Molto Alto
# 114   Molto Alto          Molto Alto
# 141        Basso               Basso
# 174   Molto Alto          Molto Alto
# 180          NaN                 NaN
# 198   Molto Alto          Molto Alto
# 200         Alto                Alto
# 226        Basso               Medio
# 240          NaN                 NaN
# 259   Molto Alto          Molto Alto
# 305   Molto Alto          Molto Alto
# 360          NaN                 NaN
# 406   Molto Alto          Molto Alto
# 408        Medio               Medio
# 415        Medio               Basso
# 417   Molto Alto          Molto Alto
#
#     average_engagement_time_per_active_user_bucket  cluster
# 25                                           Medio        2
# 66                                            Alto        2
# 100                                    Molto Basso        2
# 103                                            NaN        2
# 112                                     Molto Alto        2
# 114                                     Molto Alto        2
# 141                                          Medio        2
# 174                                     Molto Alto        2
# 180                                            NaN        2
# 198                                          Medio        2
# 200                                           Alto        2
# 226                                           Alto        2
# 240                                            NaN        2
# 259                                           Alto        2
# 305                                           Alto        2
# 360                                            NaN        2
# 406                                    Molto Basso        2
# 408                                    Molto Basso        2
# 415                                          Basso        2
# 417                                    Molto Basso        2

# %%
# Do the regression of diff_with_daily_benchmark_active_users against cluster label, one-hot-encoded

import statsmodels.api as sm

# One-hot encode the cluster labels
X = pd.get_dummies(data['cluster'], drop_first=True)
y = data['diff_with_daily_benchmark_active_users']

X = sm.add_constant(X)  # Adds a constant term to the predictor

model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 11
#       7 y = data['diff_with_daily_benchmark_active_users']
#       9 X = sm.add_constant(X)  # Adds a constant term to the predictor
# ---> 11 model = sm.OLS(y, X).fit()
#      13 # Print the regression results
#      14 print(model.summary())
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\regression\linear_model.py:921, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     918     msg = ("Weights are not supported in OLS and will be ignored"
#     919            "An exception will be raised in the next version.")
#     920     warnings.warn(msg, ValueWarning)
# --> 921 super().__init__(endog, exog, missing=missing,
#     922                           hasconst=hasconst, **kwargs)
#     923 if "weights" in self._init_keys:
#     924     self._init_keys.remove("weights")
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\regression\linear_model.py:746, in WLS.__init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     744 else:
#     745     weights = weights.squeeze()
# --> 746 super().__init__(endog, exog, missing=missing,
#     747                           weights=weights, hasconst=hasconst, **kwargs)
#     748 nobs = self.exog.shape[0]
#     749 weights = self.weights
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\regression\linear_model.py:200, in RegressionModel.__init__(self, endog, exog, **kwargs)
#     199 def __init__(self, endog, exog, **kwargs):
# --> 200     super().__init__(endog, exog, **kwargs)
#     201     self.pinv_wexog: Float64Array | None = None
#     202     self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\data.py:84, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      82     self.orig_endog = endog
#      83     self.orig_exog = exog
# ---> 84     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      86 self.const_idx = None
#      87 self.k_constant = 0
#
# File c:\Users\manuel.deluzi\OneDrive - Havas\Projects\personali\taxi_drivers\.td_ds_venv\Lib\site-packages\statsmodels\base\data.py:509, in PandasData._convert_endog_exog(self, endog, exog)
#     507 exog = exog if exog is None else np.asarray(exog)
#     508 if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509     raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                      "Check input data with np.asarray(data).")
#     511 return super()._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Using cached statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from statsmodels) (2.0.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\manuel.deluzi\onedrive - havas\projects\personali\taxi_drivers\.td_ds_venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Using cached statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Save M matrix for later use
np.save('M_matrix.npy', M)

# %%
# Import M_matrix
M = np.load('M_matrix.npy')
# Out:
# (2862, 2862)
