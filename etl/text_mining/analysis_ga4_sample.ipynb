# %%
import pandas as pd

# %%
print("=" * 80)
print("KEY INSIGHTS - GA4 SAMPLE ANALYSIS")
print("=" * 80)

print(f"\n📊 Dataset Overview:")
print(f"   • Total articles analyzed: {len(df)}")
print(f"   • Sample ID: {df['sample_id'].iloc[0]}")
print(f"   • Extraction date: {df['extracted_at'].iloc[0]}")

print(f"\n🎯 Editorial Score:")
print(f"   • Average: {df['editorial_score'].mean():.2f}")
print(f"   • Median: {df['editorial_score'].median():.2f}")
print(f"   • Range: {df['editorial_score'].min():.2f} - {df['editorial_score'].max():.2f}")

print(f"\n📈 Performance Metrics:")
print(f"   • Total pageviews: {df['pageviews'].sum():,}")
print(f"   • Average pageviews per article: {df['pageviews'].mean():.1f}")
print(f"   • Average engagement rate: {df['engagement_rate'].mean():.4f}")
print(f"   • Average session duration: {df['avg_session_duration'].mean():.1f} seconds")

print(f"\n🔗 Correlations with Editorial Score:")
corr_with_score = correlation_matrix['editorial_score'].drop('editorial_score').sort_values(ascending=False)
for metric, corr_value in corr_with_score.items():
    print(f"   • {metric}: {corr_value:.3f}")

print(f"\n🏆 Performance Categories:")
for category, count in category_counts.items():
    percentage = (count / len(df)) * 100
    print(f"   • {category}: {count} articles ({percentage:.1f}%)")

print("\n" + "=" * 80)
# Out:
# ...
# KEY INSIGHTS - GA4 SAMPLE ANALYSIS
# ...
#
# 📊 Dataset Overview:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 print("=" * 80)
#       5 print(f"\n📊 Dataset Overview:")
# ----> 6 print(f"   • Total articles analyzed: {len(df)}")
#       7 print(f"   • Sample ID: {df['sample_id'].iloc[0]}")
#       8 print(f"   • Extraction date: {df['extracted_at'].iloc[0]}")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 9. Key Insights Summary

# %%
# Categorize articles by editorial score
df['performance_category'] = pd.cut(df['editorial_score'], 
                                     bins=[0, 25, 50, 75, 100],
                                     labels=['Low', 'Medium', 'High', 'Excellent'])

# Category distribution
category_counts = df['performance_category'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
bars = plt.bar(category_counts.index.astype(str), category_counts.values, 
               color=['#ff6b6b', '#feca57', '#48dbfb', '#1dd1a1'], 
               edgecolor='black', alpha=0.7)
plt.xlabel('Performance Category')
plt.ylabel('Number of Articles')
plt.title('Articles by Performance Category (Editorial Score)', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

# Add value labels on bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height)}',
             ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

print("\nPerformance Category Distribution:")
print(category_counts)
print(f"\nPercentages:")
print(category_counts / len(df) * 100)

# %% [markdown]
# ## 8. Performance Categories

# %%
# Bottom 10 articles by editorial score
print("\n" + "=" * 80)
print("BOTTOM 10 ARTICLES BY EDITORIAL SCORE")
print("=" * 80)

bottom_10 = df.nsmallest(10, 'editorial_score')[['pagepath', 'editorial_score', 'pageviews', 'engagement_rate']]
for idx, row in bottom_10.iterrows():
    print(f"\n{idx+1}. Score: {row['editorial_score']:.2f}")
    print(f"   Path: {row['pagepath'][:80]}...")
    print(f"   Pageviews: {row['pageviews']:,} | Engagement: {row['engagement_rate']:.4f}")

# %%
# Top 10 articles by editorial score
print("=" * 80)
print("TOP 10 ARTICLES BY EDITORIAL SCORE")
print("=" * 80)

top_10 = df.nlargest(10, 'editorial_score')[['pagepath', 'editorial_score', 'pageviews', 'engagement_rate']]
for idx, row in top_10.iterrows():
    print(f"\n{idx+1}. Score: {row['editorial_score']:.2f}")
    print(f"   Path: {row['pagepath'][:80]}...")
    print(f"   Pageviews: {row['pageviews']:,} | Engagement: {row['engagement_rate']:.4f}")

# %% [markdown]
# ## 7. Top and Bottom Performers

# %%
# Scatter plots
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Editorial Score vs Pageviews
axes[0, 0].scatter(df['editorial_score'], df['pageviews'], alpha=0.6, color='steelblue', s=50)
axes[0, 0].set_xlabel('Editorial Score')
axes[0, 0].set_ylabel('Pageviews')
axes[0, 0].set_title('Editorial Score vs Pageviews')
axes[0, 0].grid(alpha=0.3)

# Add trend line
z = np.polyfit(df['editorial_score'], df['pageviews'], 1)
p = np.poly1d(z)
axes[0, 0].plot(df['editorial_score'], p(df['editorial_score']), "r--", alpha=0.8, linewidth=2)

# Editorial Score vs Engaged Sessions
axes[0, 1].scatter(df['editorial_score'], df['engaged_sessions'], alpha=0.6, color='coral', s=50)
axes[0, 1].set_xlabel('Editorial Score')
axes[0, 1].set_ylabel('Engaged Sessions')
axes[0, 1].set_title('Editorial Score vs Engaged Sessions')
axes[0, 1].grid(alpha=0.3)

z = np.polyfit(df['editorial_score'], df['engaged_sessions'], 1)
p = np.poly1d(z)
axes[0, 1].plot(df['editorial_score'], p(df['editorial_score']), "r--", alpha=0.8, linewidth=2)

# Editorial Score vs Avg Session Duration
axes[1, 0].scatter(df['editorial_score'], df['avg_session_duration'], alpha=0.6, color='lightgreen', s=50)
axes[1, 0].set_xlabel('Editorial Score')
axes[1, 0].set_ylabel('Avg Session Duration (sec)')
axes[1, 0].set_title('Editorial Score vs Avg Session Duration')
axes[1, 0].grid(alpha=0.3)

z = np.polyfit(df['editorial_score'], df['avg_session_duration'], 1)
p = np.poly1d(z)
axes[1, 0].plot(df['editorial_score'], p(df['editorial_score']), "r--", alpha=0.8, linewidth=2)

# Editorial Score vs Engagement Rate
axes[1, 1].scatter(df['editorial_score'], df['engagement_rate'], alpha=0.6, color='plum', s=50)
axes[1, 1].set_xlabel('Editorial Score')
axes[1, 1].set_ylabel('Engagement Rate')
axes[1, 1].set_title('Editorial Score vs Engagement Rate')
axes[1, 1].grid(alpha=0.3)

z = np.polyfit(df['editorial_score'], df['engagement_rate'], 1)
p = np.poly1d(z)
axes[1, 1].plot(df['editorial_score'], p(df['editorial_score']), "r--", alpha=0.8, linewidth=2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Editorial Score vs Performance Metrics

# %%
# Correlation matrix
metrics = ['pageviews', 'engaged_sessions', 'avg_session_duration', 'engagement_rate', 'editorial_score']
correlation_matrix = df[metrics].corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, 
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix - Performance Metrics vs Editorial Score', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print("\nCorrelation with Editorial Score:")
print(correlation_matrix['editorial_score'].sort_values(ascending=False))

# %% [markdown]
# ## 5. Correlation Analysis

# %%
# Pageviews distribution
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Pageviews histogram
axes[0, 0].hist(df['pageviews'], bins=30, color='coral', edgecolor='black', alpha=0.7)
axes[0, 0].set_xlabel('Pageviews')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Distribution of Pageviews')
axes[0, 0].grid(axis='y', alpha=0.3)

# Engaged sessions
axes[0, 1].hist(df['engaged_sessions'], bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('Engaged Sessions')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Distribution of Engaged Sessions')
axes[0, 1].grid(axis='y', alpha=0.3)

# Average session duration
axes[1, 0].hist(df['avg_session_duration'], bins=30, color='skyblue', edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('Avg Session Duration (seconds)')
axes[1, 0].set_ylabel('Frequency')
axes[1, 0].set_title('Distribution of Avg Session Duration')
axes[1, 0].grid(axis='y', alpha=0.3)

# Engagement rate
axes[1, 1].hist(df['engagement_rate'], bins=30, color='plum', edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Engagement Rate')
axes[1, 1].set_ylabel('Frequency')
axes[1, 1].set_title('Distribution of Engagement Rate')
axes[1, 1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Performance Metrics Analysis

# %%
# Editorial score distribution
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Histogram
axes[0].hist(df['editorial_score'], bins=20, color='steelblue', edgecolor='black', alpha=0.7)
axes[0].axvline(df['editorial_score'].mean(), color='red', linestyle='--', linewidth=2, label=f'Mean: {df["editorial_score"].mean():.2f}')
axes[0].axvline(df['editorial_score'].median(), color='green', linestyle='--', linewidth=2, label=f'Median: {df["editorial_score"].median():.2f}')
axes[0].set_xlabel('Editorial Score')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution of Editorial Scores')
axes[0].legend()
axes[0].grid(axis='y', alpha=0.3)

# Box plot
axes[1].boxplot(df['editorial_score'], vert=True)
axes[1].set_ylabel('Editorial Score')
axes[1].set_title('Editorial Score Box Plot')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nEditorial Score Statistics:")
print(f"  Mean: {df['editorial_score'].mean():.2f}")
print(f"  Median: {df['editorial_score'].median():.2f}")
print(f"  Std Dev: {df['editorial_score'].std():.2f}")
print(f"  Min: {df['editorial_score'].min():.2f}")
print(f"  Max: {df['editorial_score'].max():.2f}")

# %% [markdown]
# ## 3. Editorial Score Analysis

# %%
# Statistical summary
df.describe()

# %%
# Data info
print("Dataset Information:")
print("=" * 60)
df.info()
print("\nMissing values:")
print(df.isnull().sum())

# %%
# Display first few rows
df.head(10)

# %% [markdown]
# ## 2. Data Overview

# %%
# Load the data
csv_file = "output/ga4_sample_100articles_20260210_144147.csv"
df = pd.read_csv(csv_file)

print(f"✓ Loaded {len(df)} articles from {csv_file}")
print(f"✓ Columns: {', '.join(df.columns)}")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import json

# Configure visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print("✓ Libraries imported successfully")

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %% [markdown]
# # GA4 Sample Analysis - 100 Articles
#
# This notebook analyzes a random sample of 100 articles extracted from Google Analytics 4, including performance metrics and editorial scores.
#
# **Dataset**: `ga4_sample_100articles_20260210_144147.csv`
#
# **Metrics analyzed**:
# - `pageviews`: Total page views
# - `engaged_sessions`: Number of engaged sessions
# - `avg_session_duration`: Average time spent on page
# - `engagement_rate`: User engagement rate
# - `editorial_score`: Calculated editorial quality score (0-100)
